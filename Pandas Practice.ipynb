# %%
import numpy as np
import pandas as pd

# %%
Dict1={
    'Name':['Saad','Zubair','Mudassir','Talha','Ayan','Haris'],
    'Marks':[70,80,75,99,88,96],
    'City':['Karachi','Karachi','DG Khan','DG Khan','Karachi','Karachi']
      }

# %%
dfnew=pd.DataFrame(Dict1)

# %%
dfnew
# Out:
#        Name  Marks     City
# 0      Saad     70  Karachi
# 1    Zubair     80  Karachi
# 2  Mudassir     75  DG Khan
# 3     Talha     99  DG Khan
# 4      Ayan     88  Karachi
# 5     Haris     96  Karachi

# %%
df=pd.read_excel("Marks.xlsx")

# %%
M2 =pd.read_excel('C:\\Users\\Javeria\\Pandas\\Marks.xlsx',sheet_name='Sheet1')

# %%
M2
# Out:
#    Id2     Name2  Marks2    City2
# 0    1    Zubair      80  Karachi
# 1    2  Mudassir      75  DG Khan
# 2    3     Talha      99  DG Khan
# 3    4      Ayan      88  Karachi
# 4    5     Haris      96  Karachi

# %%
df.to_csv("Marks_Index_False.csv",index=False)

# %%
df.head(3)
# Out:
#    Id1      Name  Marks     City
# 0    1    Zubair     80  Karachi
# 1    2  Mudassir     75  DG Khan
# 2    3     Talha     99  DG Khan

# %%
df.tail(3)
# Out:
#    Id1   Name  Marks     City
# 2    3  Talha     99  DG Khan
# 3    4   Ayan     88  Karachi
# 4    5  Haris     96  Karachi

# %%
df.describe()
# Out:
#             Id1      Marks
# count  5.000000   5.000000
# mean   3.000000  87.600000
# std    1.581139  10.212737
# min    1.000000  75.000000
# 25%    2.000000  80.000000
# 50%    3.000000  88.000000
# 75%    4.000000  96.000000
# max    5.000000  99.000000

# %%
Train =pd.read_csv('C:\\Users\\Javeria\\Pandas\\Train_Number.csv')

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train['ID']
# Out:
# 0    50
# 1     2
# 2     3
# Name: ID, dtype: int64

# %%
Train['ID'][0]
# Out:
# 50

# %%
Train['ID'][0]=50
# Out:
# C:\Users\Javeria\AppData\Local\Temp/ipykernel_8688/3234538414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['ID'][0]=50

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train.to_csv("Train_Number.csv",index=False)

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train.index=['a','b','c']

# %%
Train
# Out:
#           Train     City  ID
# a  Allama Iqbal  Karachi  50
# b     Karakoram  Karachi   2
# c      Khanbaba      KPK   3

# %%
ser=pd.Series(np.random.rand(10),index=np.arange(10))#Includes only 1 column

# %%
ser
# Out:
# 0    0.014382
# 1    0.767303
# 2    0.543976
# 3    0.404361
# 4    0.362428
# 5    0.956373
# 6    0.643082
# 7    0.237979
# 8    0.448138
# 9    0.431254
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand
rows x 5 columns]

# %%
newdf.sort_index(axis=1,ascending=False) #Axis=1 means columns
# Out:
#             4         3         2         1         0
# 0    0.504023  0.757006  0.844709  0.266634  0.095724
# 1    0.987832  0.452124  0.973395  0.227785  0.588305
# 2    0.209327  0.713591  0.014473  0.275833  0.388344
# 3    0.603738  0.366333  0.400021  0.840021  0.973651
# 4    0.220199  0.759991  0.629298  0.562712  0.833375
# ..        ...       ...       ...       ...       ...
# 295  0.503813  0.499651  0.103183  0.728315  0.080884
# 296  0.691943  0.000894  0.423876  0.085570  0.400186
# 297  0.415837  0.768731  0.693699  0.208208  0.337442
# 298  0.606723  0.400047  0.482702  0.757613  0.215622
# 299     Babar  0.699280  0.717541  0.758425  0.025431
#
# [300 rows x 5 columns]

# %%
newdf[4]
# Out:
# 0      0.504023
# 1      0.987832
# 2      0.209327
# 3      0.603738
# 4      0.220199
#          ...
# 295    0.503813
# 296    0.691943
# 297    0.415837
# 298    0.606723
# 299       Babar
# Name: 4, Length: 300, dtype: object

# %%
type(newdf[4])
# Out:
# pandas.core.series.Series

# %%
newdf2=newdf #View: changes in newdf2 will make changes in newdf

# %%
newdf3=newdf.copy() #Copy(): It will make copy of newdf

# %%
newdf.columns=list('ABCDE')

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  0.095724  0.266634  0.844709  0.757006  0.504023
# 1  0.588305  0.227785  0.973395  0.452124  0.987832

# %%
newdf['B'][0]=0.111
# Out:
# C:\Users\Javeria\AppData\Local\Temp/ipykernel_8688/479620265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['B'][0]=0.111

# %%
newdf.loc[0,'B']=0.999

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  0.095724  0.999000  0.844709  0.757006  0.504023
# 1  0.588305  0.227785  0.973395  0.452124  0.987832

# %%
newdf4=newdf.drop(0,axis=0)

# %%
newdf4
# Out:
#             A         B         C         D         E
# 1    0.588305  0.227785  0.973395  0.452124  0.987832
# 2    0.388344  0.275833  0.014473  0.713591  0.209327
# 3    0.973651  0.840021  0.400021  0.366333  0.603738
# 4    0.833375  0.562712  0.629298  0.759991  0.220199
# 5    0.247475  0.069768  0.562338  0.188725  0.185313
# ..        ...       ...       ...       ...       ...
# 295  0.080884  0.728315  0.103183  0.499651  0.503813
# 296  0.400186  0.085570  0.423876  0.000894  0.691943
# 297  0.337442  0.208208  0.693699  0.768731  0.415837
# 298  0.215622  0.757613  0.482702  0.400047  0.606723
# 299  0.025431  0.758425  0.717541  0.699280     Babar
#
# [299 rows x 5 columns]

# %%
newdf4=newdf.drop('E',axis=1)

# %%
newdf4
# Out:
#             A         B         C         D
# 0    0.095724  0.999000  0.844709  0.757006
# 1    0.588305  0.227785  0.973395  0.452124
# 2    0.388344  0.275833  0.014473  0.713591
# 3    0.973651  0.840021  0.400021  0.366333
# 4    0.833375  0.562712  0.629298  0.759991
# ..        ...       ...       ...       ...
# 295  0.080884  0.728315  0.103183  0.499651
# 296  0.400186  0.085570  0.423876  0.000894
# 297  0.337442  0.208208  0.693699  0.768731
# 298  0.215622  0.757613  0.482702  0.400047
# 299  0.025431  0.758425  0.717541  0.699280
#
# [300 rows x 4 columns]

# %%
newdf4.loc[:,['A','B']]
# Out:
#             A         B
# 0    0.095724  0.999000
# 1    0.588305  0.227785
# 2    0.388344  0.275833
# 3    0.973651  0.840021
# 4    0.833375  0.562712
# ..        ...       ...
# 295  0.080884  0.728315
# 296  0.400186  0.085570
# 297  0.337442  0.208208
# 298  0.215622  0.757613
# 299  0.025431  0.758425
#
# [300 rows x 2 columns]

# %%
newdf4.loc[[1,2],:]
# Out:
#           A         B         C         D
# 1  0.588305  0.227785  0.973395  0.452124
# 2  0.388344  0.275833  0.014473  0.713591

# %%
newdf4.loc[(newdf4['A']<0.2)]
# Out:
#             A         B         C         D
# 0    0.095724  0.999000  0.844709  0.757006
# 17   0.015923  0.944268  0.081772  0.155673
# 20   0.099519  0.533902  0.471814  0.950523
# 29   0.162575  0.014008  0.266546  0.375640
# 35   0.106764  0.833086  0.141496  0.739258
# 46   0.069722  0.803856  0.777154  0.868964
# 50   0.028010  0.449690  0.700891  0.484967
# 54   0.144275  0.780271  0.996484  0.586363
# 60   0.066808  0.517651  0.056335  0.502855
# 70   0.161552  0.266543  0.728760  0.910985
# 72   0.004571  0.963636  0.075908  0.162697
# 73   0.038169  0.551119  0.323638  0.327394
# 83   0.115911  0.390624  0.299372  0.951911
# 86   0.054116  0.934720  0.621544  0.887199
# 94   0.030337  0.213523  0.862034  0.380211
# 97   0.091926  0.484434  0.655273  0.528682
# 99   0.042579  0.231310  0.905788  0.756082
# 105  0.011120  0.395967  0.174428  0.708249
# 118  0.104485  0.350299  0.383447  0.985091
# 122  0.026132  0.930037  0.360045  0.823887
# ...

# %%
newdf4.loc[(newdf4['A']<0.2) & (newdf4['B']<0.1)]
# Out:
#             A         B         C         D
# 29   0.162575  0.014008  0.266546  0.375640
# 179  0.096436  0.050166  0.303155  0.549005
# 255  0.150067  0.083090  0.635775  0.485863

# %%
newdf.iloc[0,4]
# Out:
# 0.5040231972524469

# %%
newdf.iloc[[0,4],[4,4]]#Fisrt rows and then Columns
# Out:
#           E         E
# 0  0.504023  0.504023
# 4  0.220199  0.220199

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0  0.095724  0.999000  0.844709  0.757006  0.504023
# 1  0.588305  0.227785  0.973395  0.452124  0.987832
# 2  0.388344  0.275833  0.014473  0.713591  0.209327
# 3  0.973651  0.840021  0.400021  0.366333  0.603738
# 4  0.833375  0.562712  0.629298  0.759991  0.220199

# %%
newdf.drop([0],inplace=True)

# %%
newdf.drop(['A'],axis=1 )#inplace=true updates the same DataFrame
# Out:
#             B         C         D         E
# 1    0.227785  0.973395  0.452124  0.987832
# 2    0.275833  0.014473  0.713591  0.209327
# 3    0.840021  0.400021  0.366333  0.603738
# 4    0.562712  0.629298  0.759991  0.220199
# 5    0.069768  0.562338  0.188725  0.185313
# ..        ...       ...       ...       ...
# 295  0.728315  0.103183  0.499651  0.503813
# 296  0.085570  0.423876  0.000894  0.691943
# 297  0.208208  0.693699  0.768731  0.415837
# 298  0.757613  0.482702  0.400047  0.606723
# 299  0.758425  0.717541  0.699280     Babar
#
# [299 rows x 4 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             A         B         C         D         E
# 0    0.588305  0.227785  0.973395  0.452124  0.987832
# 1    0.388344  0.275833  0.014473  0.713591  0.209327
# 2    0.973651  0.840021  0.400021  0.366333  0.603738
# 3    0.833375  0.562712  0.629298  0.759991  0.220199
# 4    0.247475  0.069768  0.562338  0.188725  0.185313
# ..        ...       ...       ...       ...       ...
# 294  0.080884  0.728315  0.103183  0.499651  0.503813
# 295  0.400186  0.085570  0.423876  0.000894  0.691943
# 296  0.337442  0.208208  0.693699  0.768731  0.415837
# 297  0.215622  0.757613  0.482702  0.400047  0.606723
# 298  0.025431  0.758425  0.717541  0.699280     Babar
#
# [299 rows x 5 columns]

# %%
newdf.loc[:,['B']]=28

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Name: B, Length: 299, dtype: bool

# %%
newdf
# Out:
#             A   B         C         D         E
# 0    0.588305  28  0.973395  0.452124  0.987832
# 1    0.388344  28  0.014473  0.713591  0.209327
# 2    0.973651  28  0.400021  0.366333  0.603738
# 3    0.833375  28  0.629298  0.759991  0.220199
# 4    0.247475  28  0.562338  0.188725  0.185313
# ..        ...  ..       ...       ...       ...
# 294  0.080884  28  0.103183  0.499651  0.503813
# 295  0.400186  28  0.423876  0.000894  0.691943
# 296  0.337442  28  0.693699  0.768731  0.415837
# 297  0.215622  28  0.482702  0.400047  0.606723
# 298  0.025431  28  0.717541  0.699280     Babar
#
# [299 rows x 5 columns]

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, np.nan, np.nan],
                   "born": [np.nan, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [name, toy, born]
# Index: []

# %%
df.dropna(how='all')
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df1 = pd.DataFrame({"name": ['Alfred', 'Alfred', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df1.drop_duplicates(subset='name')
# Out:
#        name       toy born
# 0    Alfred       NaN  NaT
# 2  Catwoman  Bullwhip  NaT

# %%
df1.head()
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Alfred  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.drop_duplicates(subset='name',keep='first')
# Out:
#        name       toy born
# 0    Alfred       NaN  NaT
# 2  Catwoman  Bullwhip  NaT

# %%
df1.drop_duplicates(subset='name',keep='last')
# Out:
#        name        toy       born
# 1    Alfred  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.drop_duplicates(subset='name',keep=False)
# Out:
#        name       toy born
# 2  Catwoman  Bullwhip  NaT

# %%
df1.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     0 non-null      float64
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 200.0+ bytes

# %%
df1['toy'].value_counts(dropna=False)
# Out:
# NaN          1
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df1['toy'].value_counts(dropna=True) #SHOW VALUES AFTER REMOVING NaN
# Out:
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df1.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False
