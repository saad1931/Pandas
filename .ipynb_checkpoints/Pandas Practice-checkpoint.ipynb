# %%
import numpy as np
import pandas as pd

# %%
Dict1={
    'Name':['Saad','Zubair','Mudassir','Talha','Ayan','Haris'],
    'Marks':[70,80,75,99,88,96],
    'City':['Karachi','Karachi','DG Khan','DG Khan','Karachi','Karachi']
      }

# %%
dfnew=pd.DataFrame(Dict1)

# %%
dfnew
# Out:
#        Name  Marks     City
# 0      Saad     70  Karachi
# 1    Zubair     80  Karachi
# 2  Mudassir     75  DG Khan
# 3     Talha     99  DG Khan
# 4      Ayan     88  Karachi
# 5     Haris     96  Karachi

# %%
df=pd.read_excel("Marks.xlsx")

# %%
M2 =pd.read_excel('C:\\Users\\Javeria\\Pandas\\Marks.xlsx',sheet_name='Sheet1')

# %%
M2
# Out:
#    Id2     Name2  Marks2    City2
# 0    1    Zubair      80  Karachi
# 1    2  Mudassir      75  DG Khan
# 2    3     Talha      99  DG Khan
# 3    4      Ayan      88  Karachi
# 4    5     Haris      96  Karachi

# %%
df.to_csv("Marks_Index_False.csv",index=False)

# %%
df.head(3)
# Out:
#        Name  Marks     City
# 0      Saad     70  Karachi
# 1    Zubair     80  Karachi
# 2  Mudassir     75  DG Khan

# %%
df.tail(3)
# Out:
#     Name  Marks     City
# 3  Talha     99  DG Khan
# 4   Ayan     88  Karachi
# 5  Haris     96  Karachi

# %%
df.describe()
# Out:
#            Marks
# count   6.000000
# mean   84.666667
# std    11.621819
# min    70.000000
# 25%    76.250000
# 50%    84.000000
# 75%    94.000000
# max    99.000000

# %%
Train =pd.read_csv('C:\\Users\\Javeria\\Pandas\\Train_Number.csv')

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train['ID']
# Out:
# 0    50
# 1     2
# 2     3
# Name: ID, dtype: int64

# %%
Train['ID'][0]
# Out:
# 50

# %%
Train['ID'][0]=50
# Out:
# C:\Users\Javeria\AppData\Local\Temp/ipykernel_10904/3234538414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['ID'][0]=50

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train.to_csv("Train_Number.csv",index=False)

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train.index=['a','b','c']

# %%
Train
# Out:
#           Train     City  ID
# a  Allama Iqbal  Karachi  50
# b     Karakoram  Karachi   2
# c      Khanbaba      KPK   3

# %%
ser=pd.Series(np.random.rand(10),index=np.arange(10))#Includes only 1 column

# %%
ser
# Out:
# 0    0.857549
# 1    0.777309
# 2    0.999270
# 3    0.628550
# 4    0.320079
# 5    0.808889
# 6    0.328566
# 7    0.784736
# 8    0.443336
# 9    0.285308
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(300,5),index=np.arange(300)) #Includes all columns and rows

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.864212  0.769879  0.754398  0.569192  0.026182
# 1    0.085547  0.726929  0.553431  0.894263  0.347849
# 2    0.208935  0.964114  0.171882  0.364804  0.547047
# 3    0.000664  0.128874  0.498970  0.960997  0.865175
# 4    0.198745  0.067666  0.868310  0.415334  0.481610
# ..        ...       ...       ...       ...       ...
# 295  0.718672  0.914176  0.686614  0.367850  0.727031
# 296  0.949602  0.225891  0.739630  0.809118  0.850398
# 297  0.189356  0.152031  0.336295  0.279377  0.518831
# 298  0.582431  0.378033  0.508034  0.141075  0.485583
# 299  0.805744  0.247687  0.887486  0.324843  0.204064
#
# [300 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newd
rows x 5 columns]

# %%
newdf.sort_index(axis=1,ascending=False) #Axis=1 means columns
# Out:
#             4         3         2         1         0
# 0    0.026182  0.569192  0.754398  0.769879  0.864212
# 1    0.347849  0.894263  0.553431  0.726929  0.085547
# 2    0.547047  0.364804  0.171882  0.964114  0.208935
# 3    0.865175  0.960997  0.498970  0.128874  0.000664
# 4     0.48161  0.415334  0.868310  0.067666  0.198745
# ..        ...       ...       ...       ...       ...
# 295  0.727031  0.367850  0.686614  0.914176  0.718672
# 296  0.850398  0.809118  0.739630  0.225891  0.949602
# 297  0.518831  0.279377  0.336295  0.152031  0.189356
# 298  0.485583  0.141075  0.508034  0.378033  0.582431
# 299     Babar  0.324843  0.887486  0.247687  0.805744
#
# [300 rows x 5 columns]

# %%
newdf[4]
# Out:
# 0      0.026182
# 1      0.347849
# 2      0.547047
# 3      0.865175
# 4       0.48161
#          ...
# 295    0.727031
# 296    0.850398
# 297    0.518831
# 298    0.485583
# 299       Babar
# Name: 4, Length: 300, dtype: object

# %%
type(newdf[4])
# Out:
# pandas.core.series.Series

# %%
newdf2=newdf #View: changes in newdf2 will make changes in newdf

# %%
newdf3=newdf.copy() #Copy(): It will make copy of newdf

# %%
newdf.columns=list('ABCDE')

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  0.864212  0.769879  0.754398  0.569192  0.026182
# 1  0.085547  0.726929  0.553431  0.894263  0.347849

# %%
newdf['B'][0]=0.111
# Out:
# C:\Users\Javeria\AppData\Local\Temp/ipykernel_10904/479620265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['B'][0]=0.111

# %%
newdf.loc[0,'B']=0.999

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  0.864212  0.999000  0.754398  0.569192  0.026182
# 1  0.085547  0.726929  0.553431  0.894263  0.347849

# %%
newdf4=newdf.drop(0,axis=0)

# %%
newdf4
# Out:
#             A         B         C         D         E
# 1    0.085547  0.726929  0.553431  0.894263  0.347849
# 2    0.208935  0.964114  0.171882  0.364804  0.547047
# 3    0.000664  0.128874  0.498970  0.960997  0.865175
# 4    0.198745  0.067666  0.868310  0.415334   0.48161
# 5    0.992827  0.904821  0.426735  0.642806  0.232273
# ..        ...       ...       ...       ...       ...
# 295  0.718672  0.914176  0.686614  0.367850  0.727031
# 296  0.949602  0.225891  0.739630  0.809118  0.850398
# 297  0.189356  0.152031  0.336295  0.279377  0.518831
# 298  0.582431  0.378033  0.508034  0.141075  0.485583
# 299  0.805744  0.247687  0.887486  0.324843     Babar
#
# [299 rows x 5 columns]

# %%
newdf4=newdf.drop('E',axis=1)

# %%
newdf4
# Out:
#             A         B         C         D
# 0    0.864212  0.999000  0.754398  0.569192
# 1    0.085547  0.726929  0.553431  0.894263
# 2    0.208935  0.964114  0.171882  0.364804
# 3    0.000664  0.128874  0.498970  0.960997
# 4    0.198745  0.067666  0.868310  0.415334
# ..        ...       ...       ...       ...
# 295  0.718672  0.914176  0.686614  0.367850
# 296  0.949602  0.225891  0.739630  0.809118
# 297  0.189356  0.152031  0.336295  0.279377
# 298  0.582431  0.378033  0.508034  0.141075
# 299  0.805744  0.247687  0.887486  0.324843
#
# [300 rows x 4 columns]

# %%
newdf4.loc[:,['A','B']]
# Out:
#             A         B
# 0    0.864212  0.999000
# 1    0.085547  0.726929
# 2    0.208935  0.964114
# 3    0.000664  0.128874
# 4    0.198745  0.067666
# ..        ...       ...
# 295  0.718672  0.914176
# 296  0.949602  0.225891
# 297  0.189356  0.152031
# 298  0.582431  0.378033
# 299  0.805744  0.247687
#
# [300 rows x 2 columns]

# %%
newdf4.loc[[1,2],:]
# Out:
#           A         B         C         D
# 1  0.085547  0.726929  0.553431  0.894263
# 2  0.208935  0.964114  0.171882  0.364804

# %%
newdf4.loc[(newdf4['A']<0.2)]
# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0  0.864212  0.999000  0.754398  0.569192  0.026182
# 1  0.085547  0.726929  0.553431  0.894263  0.347849
# 2  0.208935  0.964114  0.171882  0.364804  0.547047
# 3  0.000664  0.128874  0.498970  0.960997  0.865175
# 4  0.198745  0.067666  0.868310  0.415334   0.48161

# %%
newdf.drop([0],inplace=True)

# %%
newdf.drop(['A'],axis=1 )#inplace=true updates the same DataFrame
# Out:
#             B         C         D         E
# 1    0.726929  0.553431  0.894263  0.347849
# 2    0.964114  0.171882  0.364804  0.547047
# 3    0.128874  0.498970  0.960997  0.865175
# 4    0.067666  0.868310  0.415334   0.48161
# 5    0.904821  0.426735  0.642806  0.232273
# ..        ...       ...       ...       ...
# 295  0.914176  0.686614  0.367850  0.727031
# 296  0.225891  0.739630  0.809118  0.850398
# 297  0.152031  0.336295  0.279377  0.518831
# 298  0.378033  0.508034  0.141075  0.485583
# 299  0.247687  0.887486  0.324843     Babar
#
# [299 rows x 4 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             A         B         C         D         E
# 0    0.085547  0.726929  0.553431  0.894263  0.347849
# 1    0.208935  0.964114  0.171882  0.364804  0.547047
# 2    0.000664  0.128874  0.498970  0.960997  0.865175
# 3    0.198745  0.067666  0.868310  0.415334   0.48161
# 4    0.992827  0.904821  0.426735  0.642806  0.232273
# ..        ...       ...       ...       ...       ...
# 294  0.718672  0.914176  0.686614  0.367850  0.727031
# 295  0.949602  0.225891  0.739630  0.809118  0.850398
# 296  0.189356  0.152031  0.336295  0.279377  0.518831
# 297  0.582431  0.378033  0.508034  0.141075  0.485583
# 298  0.805744  0.247687  0.887486  0.324843     Babar
#
# [299 rows x 5 columns]

# %%
newdf.loc[:,['B']]=28

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Name: B, Length: 299, dtype: bool

# %%
newdf
# Out:
#             A   B         C         D         E
# 0    0.085547  28  0.553431  0.894263  0.347849
# 1    0.208935  28  0.171882  0.364804  0.547047
# 2    0.000664  28  0.498970  0.960997  0.865175
# 3    0.198745  28  0.868310  0.415334   0.48161
# 4    0.992827  28  0.426735  0.642806  0.232273
# ..        ...  ..       ...       ...       ...
# 294  0.718672  28  0.686614  0.367850  0.727031
# 295  0.949602  28  0.739630  0.809118  0.850398
# 296  0.189356  28  0.336295  0.279377  0.518831
# 297  0.582431  28  0.508034  0.141075  0.485583
# 298  0.805744  28  0.887486  0.324843     Babar
#
# [299 rows x 5 columns]

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, np.nan, np.nan],
                   "born": [np.nan, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df1 = pd.DataFrame({"name": ['Alfred', 'Alfred', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df1.drop_duplicates(subset='name')
# Out:
#        name       toy born
# 0    Alfred       NaN  NaT
# 2  Catwoman  Bullwhip  NaT

# %%
df1.head()
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Alfred  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.drop_duplicates(subset='name',keep='first')
# Out:
#        name       toy born
# 0    Alfred       NaN  NaT
# 2  Catwoman  Bullwhip  NaT

# %%
df1.drop_duplicates(subset='name',keep='last')
# Out:
#        name        toy       born
# 1    Alfred  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.drop_duplicates(subset='name',keep=False)
# Out:
#        name       toy born
# 2  Catwoman  Bullwhip  NaT

# %%
df1.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     0 non-null      float64
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 200.0+ bytes

# %%
df1['toy'].value_counts(dropna=False)
# Out:
# NaN          1
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df1['toy'].value_counts(dropna=True) #SHOW VALUES AFTER REMOVING NaN
# Out:
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df1.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False
