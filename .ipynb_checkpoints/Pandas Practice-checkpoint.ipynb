# %%
import numpy as np
import pandas as pd

# %%
Dict1={
    'Name':['Saad','Zubair','Mudassir','Talha','Ayan','Haris'],
    'Marks':[70,80,75,99,88,96],
    'City':['Karachi','Karachi','DG Khan','DG Khan','Karachi','Karachi']
      }

# %%
df=pd.DataFrame(Dict1)

# %%
df
# Out:
#        Name  Marks     City
# 0      Saad     70  Karachi
# 1    Zubair     80  Karachi
# 2  Mudassir     75  DG Khan
# 3     Talha     99  DG Khan
# 4      Ayan     88  Karachi
# 5     Haris     96  Karachi

# %%
df.to_csv("Marks.csv")

# %%
df.to_csv("Marks_Index_False.csv",index=False)

# %%
df.head(3)
# Out:
#        Name  Marks     City
# 0      Saad     70  Karachi
# 1    Zubair     80  Karachi
# 2  Mudassir     75  DG Khan

# %%
df.tail(3)
# Out:
#     Name  Marks     City
# 3  Talha     99  DG Khan
# 4   Ayan     88  Karachi
# 5  Haris     96  Karachi

# %%
df.describe()
# Out:
#            Marks
# count   6.000000
# mean   84.666667
# std    11.621819
# min    70.000000
# 25%    76.250000
# 50%    84.000000
# 75%    94.000000
# max    99.000000

# %%
Train =pd.read_csv('C:\\Users\\Javeria\\Pandas\\Train_Number.csv')

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi   1
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train['ID']
# Out:
# 0    1
# 1    2
# 2    3
# Name: ID, dtype: int64

# %%
Train['ID'][0]
# Out:
# 1

# %%
Train['ID'][0]=50
# Out:
# C:\Users\Javeria\AppData\Local\Temp/ipykernel_11908/3234538414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['ID'][0]=50

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train.to_csv("Train_Number.csv",index=False)

# %%
Train
# Out:
#           Train     City  ID
# 0  Allama Iqbal  Karachi  50
# 1     Karakoram  Karachi   2
# 2      Khanbaba      KPK   3

# %%
Train.index=['a','b','c']

# %%
Train
# Out:
#           Train     City  ID
# a  Allama Iqbal  Karachi  50
# b     Karakoram  Karachi   2
# c      Khanbaba      KPK   3

# %%
ser=pd.Series(np.random.rand(10),index=np.arange(10))#Includes only 1 column

# %%
ser
# Out:
# 0    0.305161
# 1    0.428522
# 2    0.618267
# 3    0.616742
# 4    0.935813
# 5    0.663592
# 6    0.365092
# 7    0.223420
# 8    0.191693
# 9    0.836560
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(300,5),index=np.arange(300)) #Includes all columns and rows

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.599400  0.884432  0.696482  0.039807  0.854923
# 1    0.655697  0.795264  0.076926  0.077670  0.436287
# 2    0.903125  0.318848  0.285561  0.579651  0.715835
# 3    0.853260  0.598271  0.002568  0.579053  0.132604
# 4    0.700091  0.669290  0.280254  0.588513  0.462243
# ..        ...       ...       ...       ...       ...
# 295  0.916215  0.138335  0.169214  0.079142  0.917209
# 296  0.999824  0.377254  0.757414  0.552146  0.740602
# 297  0.640812  0.682808  0.932207  0.006900  0.657166
# 298  0.665741  0.672854  0.479860  0.191873  0.532765
# 299  0.260138  0.630070  0.937737  0.672641  0.077900
#
# [300 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newd
rows x 5 columns]

# %%
newdf.sort_index(axis=1,ascending=False) #Axis=1 means columns
# Out:
#             4         3         2         1         0
# 0    0.854923  0.039807  0.696482      Saad  0.599400
# 1    0.436287  0.077670  0.076926  0.795264  0.655697
# 2    0.715835  0.579651  0.285561      Saad  0.903125
# 3    0.132604  0.579053  0.002568  0.598271  0.853260
# 4    0.462243  0.588513  0.280254   0.66929  0.700091
# ..        ...       ...       ...       ...       ...
# 295  0.917209  0.079142  0.169214  0.138335  0.916215
# 296  0.740602  0.552146  0.757414  0.377254  0.999824
# 297  0.657166  0.006900  0.932207  0.682808  0.640812
# 298  0.532765  0.191873  0.479860  0.672854  0.665741
# 299     Babar  0.672641  0.937737   0.63007  0.260138
#
# [300 rows x 5 columns]

# %%
newdf[4]
# Out:
# 0      0.854923
# 1      0.436287
# 2      0.715835
# 3      0.132604
# 4      0.462243
#          ...
# 295    0.917209
# 296    0.740602
# 297    0.657166
# 298    0.532765
# 299       Babar
# Name: 4, Length: 300, dtype: object

# %%
type(newdf[4])
# Out:
# pandas.core.series.Series

# %%
newdf2=newdf #View: changes in newdf2 will make changes in newdf

# %%
newdf3=newdf.copy() #Copy(): It will make copy of newdf

# %%
newdf.columns=list('ABCDE')

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  0.599400      Saad  0.696482  0.039807  0.854923
# 1  0.655697  0.795264  0.076926  0.077670  0.436287

# %%
newdf['B'][0]=0.111
# Out:
# C:\Users\Javeria\AppData\Local\Temp/ipykernel_11908/479620265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['B'][0]=0.111

# %%
newdf.loc[0,'B']=0.999

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  0.599400     0.999  0.696482  0.039807  0.854923
# 1  0.655697  0.795264  0.076926  0.077670  0.436287

# %%
newdf4=newdf.drop(0,axis=0)

# %%
newdf4
# Out:
#             A         B         C         D         E
# 1    0.655697  0.795264  0.076926  0.077670  0.436287
# 2    0.903125      Saad  0.285561  0.579651  0.715835
# 3    0.853260  0.598271  0.002568  0.579053  0.132604
# 4    0.700091   0.66929  0.280254  0.588513  0.462243
# 5    0.541161  0.162325  0.634910  0.576265  0.345081
# ..        ...       ...       ...       ...       ...
# 295  0.916215  0.138335  0.169214  0.079142  0.917209
# 296  0.999824  0.377254  0.757414  0.552146  0.740602
# 297  0.640812  0.682808  0.932207  0.006900  0.657166
# 298  0.665741  0.672854  0.479860  0.191873  0.532765
# 299  0.260138   0.63007  0.937737  0.672641     Babar
#
# [299 rows x 5 columns]

# %%
newdf4=newdf.drop('E',axis=1)

# %%
newdf4
# Out:
#             A         B         C         D
# 0    0.599400     0.999  0.696482  0.039807
# 1    0.655697  0.795264  0.076926  0.077670
# 2    0.903125      Saad  0.285561  0.579651
# 3    0.853260  0.598271  0.002568  0.579053
# 4    0.700091   0.66929  0.280254  0.588513
# ..        ...       ...       ...       ...
# 295  0.916215  0.138335  0.169214  0.079142
# 296  0.999824  0.377254  0.757414  0.552146
# 297  0.640812  0.682808  0.932207  0.006900
# 298  0.665741  0.672854  0.479860  0.191873
# 299  0.260138   0.63007  0.937737  0.672641
#
# [300 rows x 4 columns]

# %%
newdf4.loc[:,['A','B']]
# Out:
#             A         B
# 0    0.599400     0.999
# 1    0.655697  0.795264
# 2    0.903125      Saad
# 3    0.853260  0.598271
# 4    0.700091   0.66929
# ..        ...       ...
# 295  0.916215  0.138335
# 296  0.999824  0.377254
# 297  0.640812  0.682808
# 298  0.665741  0.672854
# 299  0.260138   0.63007
#
# [300 rows x 2 columns]

# %%
newdf4.loc[[1,2],:]
# Out:
#           A         B         C         D
# 1  0.655697  0.795264  0.076926  0.077670
# 2  0.903125      Saad  0.285561  0.579651
